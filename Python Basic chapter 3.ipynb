# %% [markdown]
# ## 3.1. Intro to Debugging
# ---
# ** Learning goals**
# - strategi untuk menghindari errors
# - kesalahan umum dan penyebabnya
#
# ** Tujuan **
# - identifikasi Syntax errors berdasarkan errors messages
# - menemukan ValueError, TypeError, SytaxError, ParseError, dan NameError

# %% [markdown]
# ## 3.2. Debugging
# ---
# dalam proses pemograman sering terjadi kesalahan atau bug. sedangkan proses untuk melacak dan memperbaikinya disebut dengan debugging.
#
# untuk menghindari kesalahan aau error, berikut hal-hal yang dapat dilakukan,
# - memahami masalah serta tujuan yang ingin dicapai sehingga dapat mengidentifikasi solusi yang benar
# - start small
# - progress and keep improving

# %% [markdown]
# ---
# Ask the user for the time now (in hours 0 – 23), and ask for the number of hours to wait. Your program should output what the time will be on the clock when the alarm goes off.
#
# So, where to start? The problem requires two pieces of input from the user, so lets start there and make sure we can get the data we need.

# %%
current_time = input("what is the current time (in hours)?")
wait_time = input("How many hours do you want to wait")

print(current_time)
print(wait_time)
# Out:
# 10
# 2

# %%
#debugging 1
current_time = input("what is the current time (in hours 0--23)?")
wait_time = input("How many hours do you want to wait")

print(current_time)
print(wait_time)

final_time = current_time + wait_time
print(final_time)
# Out:
# 10
# 2
# 102

# %% [markdown]
# menghasilkan 102, karena pada input 10 dan 2 dibaca sebagai string bukan integer

# %%
#debugging 2
current_time_str = input("what is the current time (in hours 0-23)?")
wait_time_str = input("How many hours do you want to wait")

current_time_int = int(current_time_str)
wait_time_int = int(wait_time_str)

final_time_int = current_time_int + wait_time_int
print(final_time_int)
# Out:
# 12

# %% [markdown]
# ketika menggunakan waktu yang lebih besar maka akan terbaca jam yang lebih dari 24, maka dibutuhkan pembagian bersisa sehingga waktu yang dihasilkan tetap berada pada interval waktu (24)

# %%
#debugging 3
current_time_str = input("what is the current time (in hours 0-23)?")
wait_time_str = input("How many hours do you want to wait")

current_time_int = int(current_time_str)
wait_time_int = int(wait_time_str)

final_time_int = current_time_int + wait_time_int

final_answer = final_time_int % 24

print("The time after waiting is: ", final_answer)
# Out:
# The time after waiting is:  12

# %% [markdown]
# ## 3.3. Beginning Tips
# ---
# 1. kesalahan dapat terjadi pada segala aspek termasuk Python sendiri, namun kesalahan pada Python harus menjadi aspek kesalahan terakhir ketika muncul error
# 2. pengujian asumsi pada setiap kemungkinan
# 3. menggunakan petunjuk seperti Error messages dan print statment

# %% [markdown]
# ## 3.4. Syntax Error
# ---
# Python dapat menjalakan suatu program ketika secara sintaks terpenuhi. ketika tidak terpenuhi maka gagal dan muncul error message. sintaks sendiri merupakan struktur dari program dan aturannya.
#
# dalam Python sendiri, 1 kesalahan dapat langsung menyebabkan sintaks tidak terpenuhi dan proses terhenti.

# %%
print("Hello World!"
# Out:
#   File "<ipython-input-5-0219726117bb>", line 1
#     print("Hello World!"
#                         ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# kesalahan: ) diakhir

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## 3.5. Runtime Errors
# ---
# selain SyntaxError, kesalahan lain adalah Runtime Errors yaitu kesalahan yang muncul setelah program dijalankan. kesalahan ini jarang muncul pada program sederhana.

# %%
A = int(input("angka pertama"))
B = int(input("angka kedua"))

pembagian = A/B

print("hasil pembagian angka pertama dan kedua", pembagian)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-7-4d1dd331e937> in <module>
#       2 B = int(input("angka kedua"))
#       3
# ----> 4 pembagian = A/B
#       5
#       6 print("hasil pembagian angka pertama dan kedua", pembagian)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# terjadi kesalahan karena input angka kedua adalah 0 atau menghasilkan inf

# %% [markdown]
# ## 3.6. Semantic Errors
# ---
# merupakan kesalahan yang terjadi dimana program akan berjalan namun akan menghasilkan output yang salah atau tidak sesuai dengan perintah tanpa adanya error message.
#
# jenis kesalahan ini lebih sulit diuraikan karena diperlukan pemahaman dan ketelitian

# %%
angka = int(input("angka yang akan dibuat persentase"))

persen = angka

print("hasil persentase",persen,"%")
# Out:
# hasil persentase 12 %

# %% [markdown]
# terjadi kesalahan hasil dari persentase 12 adalah 0.12 %

# %%
angka = int(input("angka yang akan dibuat persentase"))

persen = angka/100

print("hasil persentase",persen,"%")
# Out:
# hasil persentase 0.12 %

# %% [markdown]
# ## 3.7. Know Your Error Messages
# ---
# memahami arti dari error messages yang muncul

# %%
current_time_str = input("What is the current time (in hours 0-23)?")
wait_time_str = input("How many hours do you want to wait")

current_time_int = int(current_time_str)
wait_time_int = int(wait_time_int)

final_time_int = current_time_int + wait_time_int
print(final_time_int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-63750af14370> in <module>
#       3
#       4 current_time_int = int(current_time_str)
# ----> 5 wait_time_int = int(wait_time_int)
#       6
#       7 final_time_int = current_time_int + wait_time_int
#
# NameError: name 'wait_time_int' is not defined

# %% [markdown]
# terdapat kesalahan pada line 5 yaitu wait_time_int = int(wait_time_int) dimana wait_time_int belum didefinisikan sehingga tidak memiliki value

# %% [markdown]
# ### Exercise

# %%
current_time_str = input("What is the current time (in hours 0-23)?")
wait_time_str = input("How many hours do you want to wait"

current_time_int = int(current_time_str)
wait_time_int = int(wait_time_str)

final_time_int = current_time_int + wait_time_int
print(final_time_int)
# Out:
#   File "<ipython-input-2-9e35901f2569>", line 4
#     current_time_int = int(current_time_str)
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# kesalahan: ) pada wait_time_str

# %%
current_time_str = input("What is the "current time" (in hours 0-23)?")
wait_time_str = input("How many hours do you want to wait")

current_time_int = int(current_time_str)
wait_time_int = int(wait_time_str)

final_time_int = current_time_int + wait_time_int
print(final_time_int)
# Out:
#   File "<ipython-input-3-1a6149484c0c>", line 1
#     current_time_str = input("What is the "current time" (in hours 0-23)?")
#                                            ^
# SyntaxError: invalid syntax

# %% [markdown]
# kesalahan: double qoute pada current_time_str sehingga seharusnya input('What is the "current time" (in hours 0-23)?')

# %%
a = input('wpisz godzine')
x = input('wpisz liczbe godzin')
int(x)
int(a)
h = x // 24
s = x % 24
print (h, s)
a = a + s
print ('godzina teraz', a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-ab24c9dc8484> in <module>
#       3 int(x)
#       4 int(a)
# ----> 5 h = x // 24
#       6 s = x % 24
#       7 print (h, s)
#
# TypeError: unsupported operand type(s) for //: 'str' and 'int'

# %% [markdown]
# kesalahan: variabel a dan x masih berupa string meskipun terdapat perintah int(a) dan int(x) sehingga harus dibuat a = int(a) dan x = int(x)

# %%
str_time = input("What time is it now?")
str_wait_time = input("What is the number of hours to wait?")
time = int(str_time)
wai_time = int(str_wait_time)

time_when_alarm_go_off = time + wait_time
print(time_when_alarm_go_off)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-dc9714c26825> in <module>
#       4 wai_time = int(str_wait_time)
#       5
# ----> 6 time_when_alarm_go_off = time + wait_time
#       7 print(time_when_alarm_go_off)
#
# NameError: name 'wait_time' is not defined

# %% [markdown]
# kesalahan: penulisan nama pada line 6, wai_time -> wait_time

# %%
n = input("What time is it now (in hours)?")
n = imt(n)
m = input("How many hours do you want to wait?")
m = int(m)
sum_time = n + m
time_of_day = sum_time % 12
print("The time is now", time_of_day)

# %% [markdown]
# kesalahan: penulisan nama function imt(n) -> int(n)

# %%
present_time = input("Enter the present timein hours:")
set_alarm = input("Set the hours for alarm:")
int (present_time, set_time, alarm_time)
alarm_time = present_time + set_alarm
print(alarm_time)

# %% [markdown]
# kesalahan: penulisan variabel pada line 3, set_time -> set_alarm
