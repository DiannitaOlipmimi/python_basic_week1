# %% [markdown]
# ## 2.3 Operator dan Operand
#
# ---
#
# build complex expressions out of simpler ones using operators
# The values the operator works on are called operands.

# %%
print(18/4) #int/int = float point
# Out:
# 4.5

# %%
print(18.0//4) #float/int = float
# Out:
# 4.0

# %%
print(18%4) #sisa pembagian/remainder
# Out:
# 2

# %% [markdown]
# ## 2.2.1 Order of Operations
#
# ---
# When more than one operator appears in an expression, the order of evaluation depends on the rules of precedence. Python follows the same precedence rules for its mathematical operators that mathematics does.

# %%
print(16 - 2 * 5 // 3 + 1)
# Out:
# 14

# %% [markdown]
# ## 2.4 Function Cells
#
# ---
#
# The Python interpreter can compute new values with function calls, using one or more input (arguments).

# %%
def square(x):
   return x * x

def sub(x, y):
   return x - y

# %%
print(square(3))
square(5) # compute only 
print(sub(6, 4)) # function - dg 2 input
print(sub(5, 9))
# Out:
# 9
# 2
# -4

# %% [markdown]
# ### Complex expression in function

# %%
print(square(3) + 2)
print(sub(square(3), square(1+1)))
# Out:
# 11
# 5

# %%
print(square) 
print(square(3)) # () -> invokes function
# Out:
# <function square at 0x7f6f00f91320>
# 9

# %% [markdown]
# ## 2.5 Data Types
#
# ---
# using type() to determine the class or data type

# %%
print(type("Hello, World!")) #string
print(type(17)) #int
print("Hello, World") 
print(type(3.2)) #float
# Out:
# <class 'str'>
# <class 'int'>
# Hello, World
# <class 'float'>

# %%
print(type("17")) #string karena ""
print(type("3.2"))
# Out:
# <class 'str'>
# <class 'str'>

# %%
#macam macam tanda petik -> string
print(type('This is a string.'))
print(type("And so is this."))
print(type("""and this."""))
print(type('''and even this...'''))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %%
#double quatation
print("Bruce's beard")
print('The knights who say "Ni!"')
print('''"Oh no", she exclaimed, "Ben's bike is broken!"''')
# Out:
# Bruce's beard
# The knights who say "Ni!"
# "Oh no", she exclaimed, "Ben's bike is broken!"

# %%
print("""This message will span
several lines
of the text.""")
# Out:
# This message will span
# several lines
# of the text.

# %%
print('This is a string.')
print("""And so is this.""")
# Out:
# This is a string.
# And so is this.

# %%
print(42500)
print(42,500)
# Out:
# 42500
# 42 500

# %%
print(42, 17, 56, 34, 11, 4.35, 32)
print(3.4, "hello", 45)

# %% [markdown]
# ## 2.6. Type conversion functions
#
# ---
# mengubah tipe value dengan menggunakan function int, float, dan string.

# %%
print(3.14, int(3.14)) #float -> int 
print(3.9999, int(3.9999)) #float -> int
print(3.0, int(3.0))
print(-3.999, int(-3.999))     
print("2345", int("2345"))       
print(17, int(17))                
print(int("23bottles")) #string -/-> int
# Out:
# 3.14 3
# 3.9999 3
# 3.0 3
# -3.999 -3
# 2345 2345
# 17 17
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-830718b01071> in <module>
#       5 print("2345", int("2345"))
#       6 print(17, int(17))
# ----> 7 print(int("23bottles"))
#
# ValueError: invalid literal for int() with base 10: '23bottles'

# %%
print(float("123.45"))
print(type(float("123.45"))) #tipe value
# Out:
# 123.45
# <class 'float'>

# %%
print(str(17))
print(str(123.45))
print(type(str(123.45))) #value tipe string
# Out:
# 17
# 123.45
# <class 'str'>

# %% [markdown]
# ### contoh penggunaan

# %%
val= 50 + 57
print("the value = " + str(val))
# Out:
# the value = 107

# %%
print(int(53.785))
# Out:
# 53

# %% [markdown]
# ## 2.7. Variabel
# ---
# variabel dalam pyhton digunakan untuk menyimpan value dengan nama yang human readable. berikut contoh variabel, penggunaan, dan aturan nama variabel.

# %%
#set variabel
message = "What's up, Doc?"
n = 17
pi = 3.14159

#reference variabel
print(message)
print(n)
print(pi)
# Out:
# What's up, Doc?
# 17
# 3.14159

# %%
#overwrite variabel
day = "Thursday"
print(day)
day = "Friday"
print(day)
day = 21
print(day)
# Out:
# Thursday
# Friday
# 21

# %%
message = "What's up, Doc?"
n = 17
pi = 3.14159

print(type(message)) #tipe value dalam variabel
print(type(n))
print(type(pi))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
day = "Thursday"
day = 32.5
day = 19
print(day)
# Out:
# 19

# %% [markdown]
# hanya akan menghasilkan value terakhir dari variabel

# %% [markdown]
# ## 2.8. Variable names and keywords
# ---
# ### aturan penulisan nama dalam variabel
# ---
# 1. selalu diawal dengan huruf
# 2. dapat terdiri dari huruf dan angka
# 3. lowercase != uppercase
# 4. tidak dapat menggunakan spasi
# 5. terdapat kata yang tidak dapat digunakan seperti lambda (python reserved keywords)

# %%
76trombones = "big parade"
more$ = 1000000
class = "Computer Science 101"
# Out:
#   File "<ipython-input-16-738a78e2a131>", line 1
#     76trombones = "big parade"
#       ^
# SyntaxError: invalid syntax

# %%
A_good_grade_is_A+
# Out:
#   File "<ipython-input-17-c150cc88963c>", line 1
#     A_good_grade_is_A+
#                       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2.9. Pemilihan nama variabel
# ---
# ### Overwrite variabel

# %%
bruce = 5
print(bruce)
bruce = 7
print(bruce)
# Out:
# 5
# 7

# %%
a = 5
b = a    # after executing this line, a and b are now equal
print(a,b)
a = 3    # after executing this line, a and b are no longer equal
print(a,b)
# Out:
# 5 5
# 3 5

# %%
a = 5
b = a
print(a, b)
a = 3
print(a, b)
# Out:
# 5 5
# 3 5

# %%
x = 15
y = x
x = 22
print(x, y)
# Out:
# 22 15

# %% [markdown]
# ## 2.10. Statment and Expression
# ---
# Statment merupakan instruksi yang dijalankan oleh python interpreter. sedangkan Expression adalah kombinasi dari nama variabel, operator, bahkan function. evaluasi dari Expression adalah value atau object.

# %%
print(1 + 1 + (2 * 3))
print(len("hello"))
# Out:
# 8
# 5

# %%
y = 3.14
x = len("hello")
print(x)
print(y)
# Out:
# 5
# 3.14

# %%
print(2 * len("hello") + len("goodbye"))
# Out:
# 17

# %%
def square(x):
   return x * x

def sub(x, y):
   return x - y

# %%
x = 2
y = 1
print(square(y + 3))
print(square(y + square(x)))
print(sub(square(y), square(x)))
# Out:
# 16
# 25
# -3

# %% [markdown]
# ## 2.11. Order of Operation
# ---
# ketika muncul lebih dari 1 operasi dalam expression maka urutan dalam operasi akan mengikuti *rules of precedence*

# %%
print(2 ** 3 ** 2)     #ekponen berjalan dari R-L
print((2 ** 3) ** 2)   #() untul L-R
# Out:
# 512
# 64

# %%
16 - 2 * 5 // 3 + 1
# Out:
# 14

# %% [markdown]
# ## 2.13. Update variabel
# ---
# melakukan update atau perubahan value berdasarkan value yang lama. update variabel dengan menambah value disebut dengan increment; mengurangi disebut decrement. apabila tidak disebutkan banyaknya penambahan atau pengurangan maka nilainya 1. sedangkan bumping variabel adalah menambah 1.
#
# += adalah increment
# -=  adalah decrement

# %%
x = 6        
print(x)
x = x + 1    # update x
print(x)
# Out:
# 6
# 7

# %%
x = 6        
print(x)
x += 3       # increment 3 atau x = x + 3
print(x)
x -= 1       # decrement 1
print(x)
# Out:
# 6
# 9
# 8

# %%
s = 1
print(s)
s = s + 2
print(s)
s = s + 3
print(s)
s = s + 4
print(s)
s = s + 5
print(s)
s = s + 6
print(s)
s = s + 7
print(s)
s = s + 8
print(s)
s = s + 9
print(s)
s = s + 10
print(s)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55

# %%
x = 12
x = x - 1
print(x)
# Out:
# 11

# %%
x = 12
x = x - 3
x = x + 5
x = x + 1
print(x)
# Out:
# 15

# %%
mybankbalance = 100
mybankbalance = mybankbalance + 34
print(mybankbalance)
# Out:
# 134

# %% [markdown]
# ## 2.14. Hard-Coding
# ---
# hard coding merupakan penyelesaian masalah dengan menuliskannya hasil secara langsung tanpa menggunakan bergantug pada code, logika, ataupun function

# %%
x = 20
y = 35

z = 55 #hard coding

z = x + y
print(z)
# Out:
# 55

# %%
x = 10
y = 20
 
avg = 15.0 #hard coding

avg = (x + y) / 2
print(avg)
# Out:
# 15.0

# %% [markdown]
# ## 2.15 Input
# ---
# input function dapat digunakan untuk memunculkan prompt string atau pop up windows pada browser ketika function dijalankan sehingga user dapat memasukan text dan akan return ke input.

# %%
n = input("Please enter your name: ")
print("Hello", n)
# Out:
# Hello Diannita

# %% [markdown]
# ### contoh input dalam konversi detik ke jam dan menit serta merubah text atau string menjadi integer.

# %%
str_seconds = input("Please enter the number of seconds you wish to convert") #input function
total_secs = int(str_seconds) #strinr -> int

hours = total_secs // 3600
secs_still_remaining = total_secs % 3600
minutes =  secs_still_remaining // 60
secs_finally_remaining = secs_still_remaining  % 60

print("Hrs=", hours, "mins=", minutes, "secs=", secs_finally_remaining)
# Out:
# Hrs= 1 mins= 0 secs= 0

# %%
n = input("Please enter your age: ")
print(type(n))
# Out:
# <class 'str'>

# %% [markdown]
# ## Exercise 2
# ---
# Evaluate the following numerical expressions in your head, then use the active code window to check your results:

# %%
print(5**2)
print(9*5)
print(15/12)
print(12/15)
print(15//12)
print(12//15)
print(5%2)
print(9%5)
print(15%12)
print(12%15)
print(6%6)
print(0%7)
# Out:
# 25
# 45
# 1.25
# 0.8
# 1
# 0
# 1
# 4
# 3
# 12
# 0
# 0

# %% [markdown]
# ###
# What is the order of the arithmetic operations in the following expression. Evaluate the expression by hand and then check your work.

# %%
a = 2 + (3 - 1) * 10 / 5 * (2 + 3)

A = 22

print(a, A)
# Out:
# 22.0 22

# %% [markdown]
# Challenge: Many people keep time using a 24 hour clock (11 is 11am and 23 is 11pm, 0 is midnight). If it is currently 13 and you set your alarm to go off in 50 hours, it will be 15 (3pm). Write a Python program to solve the general version of the above problem. Ask the user for the time now (in hours), and then ask for the number of hours to wait for the alarm. Your program should output what the time will be on the clock when the alarm goes off.

# %%
str_time = input("please enter the time now")
str_hours = input("please enter the number of hours to wait for the alarm")

total_time = int(str_time)
total_hours = int(str_hours)

hours = total_time + total_hours
total_alarm = hours % 24

print("alarm goes off =", total_alarm)
# Out:
# alarm goes off = 15

# %% [markdown]
# It is possible to name the days 0 thru 6 where day 0 is Sunday and day 6 is Saturday. If you go on a wonderful holiday leaving on day number 3 (a Wednesday) and you return home after 10 nights you would return home on a Saturday (day 6). Write a general version of the program which asks for the starting day number, and the length of your stay, and it will tell you the number of day of the week you will return on.

# %%
str_starting_day = input("please input the number of starting day")
str_length_day = input("please input the number of your stay")

total_starting_day = int(str_starting_day)
total_length_day = int(str_length_day)

day_return = total_starting_day + total_length_day
day_return_number = day_return % 7

print("number of day you return =",day_return_number)

print(type(day_return_number))

if day_return_number == 0 :
    print("sunday")
elif day_return_number == 1 :
    print("monday")
elif day_return_number == 2 :
    print("Tuesday")
elif day_return_number == 3 :
    print("wednesday")
elif day_return_number == 4 :
    print("thursday")
elif day_return_number == 5 :
    print("friday")
else  :
    print("saturday")
# Out:
# number of day you return = 6
# <class 'int'>
# saturday

# %% [markdown]
# Challenge: Take the sentence: All work and no play makes Jack a dull boy. Store each word in a separate variable, then print out the sentence on one line using print.

# %%
sentence = "All work and no play makes Jack a dull boy"

word1=sentence[0:3]
word2=sentence[4:8]
word3=sentence[9:12]
word4=sentence[13:15]
word5=sentence[16:20]
word6=sentence[21:26]
word7=sentence[27:31]
word8=sentence[32:33]
word9=sentence[34:38]
word10=sentence[39:42]

print(word1+" "+word2+" "+word3+" "+word4+
      " "+word5+" "+word6+" "+word7+" "+word8+" "+
      word9+" "+word10)
# Out:
# All work and no play makes Jack a dull boy

# %% [markdown]
# Add parentheses to the expression 6 * 1 - 2 to change its value from 4 to -6.

# %%
print(6 * (1 -2))
# Out:
# -6

# %% [markdown]
# Challenge: The formula for computing the final amount if one is earning compound interest is given on Wikipedia as
#
# formula for compound interest
# Write a Python program that assigns the principal amount of 10000 to variable P, assign to n the value 12, and assign to r the interest rate of 8% (0.08). Then have the program prompt the user for the number of years, t, that the money will be compounded for. Calculate and print the final amount after t years.

# %%
P = 10000
n = 12
r = 0.08

str_t = input("please input the number of years")
t=int(str_t)

A=P*((1+r/n)**(n*t))
print(A)
# Out:
# 4.248727227595447e+38

# %% [markdown]
# Write a program that will compute the area of a circle. Prompt the user to enter the radius and save it to avariable called radius. Print a nice message back to the user with the answer.

# %%
pi = 3.14

radius=int(input("please input the number of the radius"))

area_circle=pi*(radius**2)

print("the area of the circle with",radius,"is =", area_circle, "\n")
# Out:
# the area of the circle with 10 is = 314.0

# %% [markdown]
# Challenge: Write a program that will compute the area of a rectangle. Prompt the user to enter the width and height of the rectangle and store the values in variables called width and height. Print a nice message with the answer..

# %%
width = int(input("please input the width of rectangle"))
height = int(input("please input the heigth of rectangle"))

area_rectangle = width*height

print("the area of the rectangle with width",
      width,"and height",height,"is =", area_rectangle, "\n")
# Out:
# the area of the rectangle with width 10 and height 10 is = 100

# %% [markdown]
# Write a program that will compute MPG for a car. Prompt the user to enter the number of miles driven and the number of gallons used. Print a nice message with the answer.

# %%
miles = int(input("please input the number of miles driven"))
gallons = int(input("please input the number of gallons used"))

MPG = miles/gallons

print("your MPG with miles driven",miles,"and gallons used",
      gallons,"is =",MPG)
# Out:
# your MPG with miles driven 100 and gallons used 2 is = 50.0

# %% [markdown]
# Challenge: Write a program that will convert degrees celsius to degrees fahrenheit.

# %%
celcius=int(input("please input the number of celcius"))

fahrenheit=(celcius*(9/5))+32

print("fahrenheit when celcius",celcius,"is =",fahrenheit)
# Out:
# fahrenheit when celcius 20 is = 68.0

# %% [markdown]
# Ask the user for the temperature in Fahrenheit and store it in a variable call deg_f. Calculate the equivalent temperature in degrees Celsius and store it in def_c. Output a message to the user giving the temperature in Celsius.

# %%
deg_f=int(input("please input the temperature(F)"))

deg_c=(deg_f-32)*(5/9)

print("celcius when fahrenheit",deg_f,"is =",deg_c,"\n")
# Out:
# celcius when fahrenheit 100 is = 37.77777777777778

# %% [markdown]
# data-18-25: Piece together the code so that a user is asked for two numbers, and then the sum of those two numbers is printed out.

# %%
num_one = input("please enter your first number:")
num_two = input("please enter your second numer")

sum_of_input = int(num_one) + int(num_two)

print(sum_of_input)
# Out:
# 5

# %% [markdown]
# data-18-27: Write a program that will convert gallons to liters. This program will also need to get input from a user to see how many gallons should be converted and the result should be printed to the user.

# %%
user_gallons = input("how many gallons should be converted?: ")

num_gallons = int(user_gallons)
litters=num_gallons*3.785

print("number of liters: " + str(litters))
# Out:
# number of liters: 378.5

# %% [markdown]
# data-18-29: Write a program that will convert table spoons to teaspons. This program will also need to get input from a user to see how many tablespoons should be converted and the result should be printed to the user.

# %%
user_tablespoons = float(input("how many tablespoons should be converted?: "))

teaspoons = user_tablespoons*3

print("number of teaspoons: " + str(teaspoons))
# Out:
# number of teaspoons: 36.0
